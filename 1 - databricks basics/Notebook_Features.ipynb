# %%
# Import necessary modules
from datetime import datetime

# %%
a = 1
b = "Hello World!"
c = ['a', 'b', 'c']
date = datetime.now()

# %%
import time
import pandas as pd

d = {'col1':[1,2], 'col2':['a', 'b']}
df = pd.DataFrame(data=d)
x= 5
time.sleep(6)
print("pre foo")
print(df)
print("post foo")
