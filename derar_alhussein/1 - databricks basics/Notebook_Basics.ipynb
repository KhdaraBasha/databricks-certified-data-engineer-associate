# %% [markdown]
# # **Header Of The Notebook**
#
# # **_Titile 1_**
#
# ## **_Titile 2_**
#
# ### **_Titile 3_**
#
# text with a **bold** and *italicized* in it.
#
# Ordered list
# - first
# - second
# - third
#
# Unordered list
# * coffee
# * tea
# * milk
#
# Images:
# ![Associate-badge](https://www.databricks.com/wp-content/uploads/2022/04/associate-badge-eng.svg)
#
# And of course, tables:
#
# | User_id | user_name |
# |---------|-----------|
# |   1     |   Adam    |
# |   2     |   Sarah   |
# |   3     |   John    |
#
# Links (or Embedded HTML): <a href="https://docs.databricks.com/notebooks/notebooks-manage.html" target="_blank"> Managing Notebooks documentation</a>

# %%
# %sql
select "Hello World!"

# %%
print("Hello World!")

# %%
# %run ./print_user_name

# %%
print(full_name)

# %%
print(result)

# %%
# %fs ls

# %%
# %fs ls 'dbfs:/databricks-datasets/'

# %%
# %fs ls 'dbfs:/Workspace/'

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
dbutils.fs.ls("dbfs:/")

# %%
x = 100

print(x)

# %%
a = 'basha'

print(a)

# %%
from datetime import datetime, timedelta

A = 1
B = 'Hello World'
C = ['a', 'b', 'c']
D = {'a': 1, 'b': 2, 'c': 3}
E = datetime.now()
F = timedelta(days=1)

print(A)
print(B)
print(C)
print(D)
print(E)
print(F)

# %%
import numpy as np
import pandas as pd
import random
import pyspark.pandas as ps
import pyspark.sql.functions as F
import pyspark.sql.types as T

# %%
my_np_arr = np.random.rand(3,3)
print(my_np_arr)
print()
my_pandas_df =  pd.DataFrame({
    'column1' : my_np_arr[:,0],
    'column2' : my_np_arr[:,1],
    'column3' : my_np_arr[:,2]

})
print(my_pandas_df)
print()

my_spark_df = ps.from_pandas(my_pandas_df)
print(my_spark_df)

my_spark_df1 = spark.createDataFrame(my_pandas_df)
print(my_spark_df1)

# %% [markdown]
# ## Python Interactive Debugger

# %%
import time
import pandas as pd

d = {
    'col1' : [1, 2],
    'col2' : [3, 4]
    }

df = pd.DataFrame(data= d)

x  = 5

time.sleep(6)

x  = 6

print("pre foo")

# foo(df)

print('done!')
